# %%
#to store marks of students in a series
import pandas as pd
marks_list=[90,95,89]
labels=['DSA','java','Python']
a=pd.Series(data=marks_list, index=labels)
print(a)
# Out:
# DSA       90
# java      95
# Python    89
# dtype: int64

# %%
dict={"Name":"Mariyam Memon","Rollno":22000252, "Program":"BCA"}
s=pd.Series(dict)
s
# Out:
# Name       Mariyam Memon
# Rollno          22000252
# Program              BCA
# dtype: object

# %%
s.values
# Out:
# array(['Mariyam Memon', 22000252, 'BCA'], dtype=object)

# %%
import numpy as np
b=np.random.randint(0,100,(4,3))
b
# Out:
# array([[49, 59,  3],
#        [35, 57,  4],
#        [77, 14, 52],
#        [ 1, 30, 54]])

# %%
s.keys()
# Out:
# Index(['Name', 'Rollno', 'Program'], dtype='object')

# %%
s=pd.DataFrame(data=b,index=["person1","person2","person3","Person4"],columns=["DS","Software","Ent"])
s
# Out:
#          DS  Software  Ent
# person1  49        59    3
# person2  35        57    4
# person3  77        14   52
# Person4   1        30   54

# %%
s["Total"]=s["DS"]+s["Software"]+s["Ent"]
s
# Out:
#          DS  Software  Ent  Total
# person1  49        59    3    111
# person2  35        57    4     96
# person3  77        14   52    143
# Person4   1        30   54     85

# %%
s["Percentage"]=s["Total"]/300*100
s
# Out:
#          DS  Software  Ent  Total  Percentage
# person1  49        59    3    111   37.000000
# person2  35        57    4     96   32.000000
# person3  77        14   52    143   47.666667
# Person4   1        30   54     85   28.333333

# %%
s.loc[["person1","person2"]]
# Out:
#          DS  Software  Ent  Total  Percentage
# person1  49        59    3    111        37.0
# person2  35        57    4     96        32.0

# %%
s.tail(1)
# Out:
#          DS  Software  Ent  Total  Percentage
# Person4   1        30   54     85   28.333333

# %%
s.loc["person1"]
# Out:
# DS             49.0
# Software       59.0
# Ent             3.0
# Total         111.0
# Percentage     37.0
# Name: person1, dtype: float64

# %%
s.loc["person2":]
# Out:
#          DS  Software  Ent  Total  Percentage
# person2  35        57    4     96   32.000000
# person3  77        14   52    143   47.666667
# Person4   1        30   54     85   28.333333

# %%
s.iloc[2:3]
# Out:
#          Software  Ent  Total  Percentage
# person3        14   52    143   47.666667

# %%
s.drop("Percentage",axis=1)
# Out:
#          Software  Ent  Total
# person1        59    3    111
# person2        57    4     96
# person3        14   52    143
# Person4        30   54     85

# %%
s
# Out:
#          Software  Ent  Total  Percentage
# person1        59    3    111   37.000000
# person2        57    4     96   32.000000
# person3        14   52    143   47.666667
# Person4        30   54     85   28.333333

# %%
s.drop("Total",axis=1,inplace=True)

# %%
s
# Out:
#          Software  Ent  Percentage
# person1        59    3   37.000000
# person2        57    4   32.000000
# person3        14   52   47.666667
# Person4        30   54   28.333333

# %%
s.drop("person1",axis=0)
# Out:
#          Software  Ent  Percentage
# person2        57    4   32.000000
# person3        14   52   47.666667
# Person4        30   54   28.333333

# %%
#create a dataframe which has productid, product name, product price
import pandas as pd
product_id=[101,102,103,104,105]
product_name=["fruit","busicuits","sweets","chair","bag"]
product_price=[200,300,400,500,250]
df=pd.DataFrame(data=[product_id,product_name,product_price],index=["product_id","product_name","product_price"])

# %%
df1=df.transpose()

# %%
df1
# Out:
#   product_id product_name product_price
# 0        101        fruit           200
# 1        102    busicuits           300
# 2        103       sweets           400
# 3        104        chair           500
# 4        105          bag           250

# %%
#to access each column
for d in df1:
    print(df1[d])
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: product_id, dtype: object
# 0        fruit
# 1    busicuits
# 2       sweets
# 3        chair
# 4          bag
# Name: product_name, dtype: object
# 0    200
# 1    300
# 2    400
# 3    500
# 4    250
# Name: product_price, dtype: object

# %%
#to access individual rows
for i in df1.iterrows():
    print(i)
# Out:
# (0, product_id         101
# product_name     fruit
# product_price      200
# Name: 0, dtype: object)
# (1, product_id             102
# product_name     busicuits
# product_price          300
# Name: 1, dtype: object)
# (2, product_id          103
# product_name     sweets
# product_price       400
# Name: 2, dtype: object)
# (3, product_id         104
# product_name     chair
# product_price      500
# Name: 3, dtype: object)
# (4, product_id       105
# product_name     bag
# product_price    250
# Name: 4, dtype: object)

# %%
df1.iloc[0]
# Out:
# product_id         101
# product_name     fruit
# product_price      200
# Name: 0, dtype: object

# %%
df1.loc[:3,["product_name"]]
# Out:
#   product_name
# 0        fruit
# 1    busicuits
# 2       sweets
# 3        chair

# %%
s
# Out:
#          Software  Ent  Percentage
# person1        59    3   37.000000
# person2        57    4   32.000000
# person3        14   52   47.666667
# Person4        30   54   28.333333

# %%
s.loc[s["Software"]<40,"Software"]=41
s
# Out:
#          Software  Ent  Percentage
# person1        59    3   37.000000
# person2        57    4   32.000000
# person3        41   52   47.666667
# Person4        41   54   28.333333

# %%
df1.isnull()
#returns true for the places where null value exists.
# Out:
#    product_id  product_name  product_price
# 0       False         False          False
# 1       False         False          False
# 2       False         False          False
# 3       False         False          False
# 4       False         False          False

# %%
df1.dropna() #drops the rows where null value exists. we can use the axis=1 attribute to drop  column
# Out:
#   product_id product_name product_price
# 0        101        fruit           200
# 1        102    busicuits           300
# 2        103       sweets           400
# 3        104        chair           500
# 4        105          bag           250

# %%
df1.notnull() #returns true when the values are not null(NaN or none)
# Out:
#    product_id  product_name  product_price
# 0        True          True           True
# 1        True          True           True
# 2        True          True           True
# 3        True          True           True
# 4        True          True           True

# %%
df1.dropna(thresh=2) # drops the rows which exceeds the thresh. thresh=2 will keep the rows that has 1 NaN value but will delete for two more
# Out:
#   product_id product_name product_price
# 0        101        fruit           200
# 1        102    busicuits           300
# 2        103       sweets           400
# 3        104        chair           500
# 4        105          bag           250

# %%
df1.fillna(value=4) # it will fill value 4 wherever Nan is
''''Methods in fillna are:-
ffil= it will fill the value of the data that was before the NaN value
bfill will give NaN the value that comes after the NaN value'''
# Out:
# 'Methods in fillna are:-\nffil= it will fill the value of the data that was before the NaN value\nbfill will give NaN the value that comes after the NaN value'

# %%
import numpy as np
df=pd.read_csv("Salaries.csv")
# Out:
# C:\Users\mariy\AppData\Local\Temp\ipykernel_14188\2497912615.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Salaries.csv")

# %%
df=df.replace("Not Provided", np.nan)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# 148649                                       Custodian       0.00        0.00
# 148650                                    Not provided        NaN         NaN
# 148651                                    Not provided        NaN         NaN
# 148652                                    Not provided        NaN         NaN
# 148653                      Counselor, Log Cabin Ranch       0.00        0.00
#
#          OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0       400184.25      NaN  567595.43         567595.43  2011    NaN
# 1       137811.38      NaN  538909.28         538909.28  2011    NaN
# 2         16452.6      NaN  335279.91         335279.91  2011    NaN
# 3        198306.9      NaN  332343.61         332343.61  2011    NaN
# 4       182234.59      NaN  326373.19         326373.19  2011    NaN
# ...           ...      ...        ...               ...   ...    ...
# 148649       0.00     0.00       0.00              0.00  2014    NaN
# 148650        NaN      NaN       0.00              0.00  2014    NaN
# 148651        NaN      NaN       0.00              0.00  2014    NaN
# 148652        NaN      NaN       0.00              0.00  2014    NaN
# 148653    -618.13     0.00    -618.13           -618.13  2014    NaN
#
#                Agency Status
# 0       San Francisco    NaN
# 1       San Francisco    NaN
# 2       San Francisco    NaN
# 3       San Francisco    NaN
# 4       San Francisco    NaN
# ...               ...    ...
# 148649  San Francisco     PT
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN
# 148653  San Francisco     PT
#
# [148654 rows x 13 columns]

# %%
df=df.replace("Not provided", np.nan)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# 148649                                       Custodian       0.00        0.00
# 148650                                             NaN        NaN         NaN
# 148651                                             NaN        NaN         NaN
# 148652                                             NaN        NaN         NaN
# 148653                      Counselor, Log Cabin Ranch       0.00        0.00
#
#          OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0       400184.25      NaN  567595.43         567595.43  2011    NaN
# 1       137811.38      NaN  538909.28         538909.28  2011    NaN
# 2         16452.6      NaN  335279.91         335279.91  2011    NaN
# 3        198306.9      NaN  332343.61         332343.61  2011    NaN
# 4       182234.59      NaN  326373.19         326373.19  2011    NaN
# ...           ...      ...        ...               ...   ...    ...
# 148649       0.00     0.00       0.00              0.00  2014    NaN
# 148650        NaN      NaN       0.00              0.00  2014    NaN
# 148651        NaN      NaN       0.00              0.00  2014    NaN
# 148652        NaN      NaN       0.00              0.00  2014    NaN
# 148653    -618.13     0.00    -618.13           -618.13  2014    NaN
#
#                Agency Status
# 0       San Francisco    NaN
# 1       San Francisco    NaN
# 2       San Francisco    NaN
# 3       San Francisco    NaN
# 4       San Francisco    NaN
# ...               ...    ...
# 148649  San Francisco     PT
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN
# 148653  San Francisco     PT
#
# [148654 rows x 13 columns]

# %%
df['BasePay']=df['BasePay'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148648 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 14.7+ MB

# %%
df['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
df['OvertimePay']=df['OvertimePay'].astype('float')

# %%
df['OvertimePay'].max()
# Out:
# 245131.88

# %% [raw]
# # Merging, Joining and Concatenating

# %%
import pandas as pd
import numpy as np

# %%
A=pd.DataFrame(data=np.random.randint(0,100,(3,3)),index=[1,2,3], columns=[1,2,3])
A
# Out:
#     1   2   3
# 1  88  54  80
# 2  10   6  29
# 3  24  90   0

# %%
B=pd.DataFrame(data=np.random.randint(0,100,(3,3)),index=[4,5,6], columns=[1,2,3])
B
# Out:
#     1   2   3
# 4  73  73  34
# 5  84  17  25
# 6  34  87  26

# %%
C=pd.DataFrame(data=np.random.randint(0,100,(3,3)),index=[7,8,9], columns=[1,2,3])
C
# Out:
#     1   2   3
# 7  75  94  57
# 8  36  57  55
# 9  58   1  96

# %%
display(A, B, C,pd.concat([A,B,C]))
# Out:
#     1   2   3
# 1  88  54  80
# 2  10   6  29
# 3  24  90   0
#     1   2   3
# 4  73  73  34
# 5  84  17  25
# 6  34  87  26
#     1   2   3
# 7  75  94  57
# 8  36  57  55
# 9  58   1  96
#     1   2   3
# 1  88  54  80
# 2  10   6  29
# 3  24  90   0
# 4  73  73  34
# 5  84  17  25
# 6  34  87  26
# 7  75  94  57
# 8  36  57  55
# 9  58   1  96

# %%
left= pd.DataFrame({'key':['K0','K2','K5','K3'],
                   'A':['A0','A2','A5','A3'],
                   'B':['B0','B2','B5','B3']})

right= pd.DataFrame({'key':['K0','K1','K2','K9'],
                   'C':['C0','C1','C2','C9'],
                   'D':['D0','D1','D2','D9']})

# %%
display(left, right, pd.merge(left, right, how='inner', on=['key']))
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K2  A2  B2
# 2  K5  A5  B5
# 3  K3  A3  B3
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K9  C9  D9
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on=['key'])
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K2   A2   B2   C2   D2
# 2  K5   A5   B5  NaN  NaN
# 3  K3   A3   B3  NaN  NaN
# 4  K1  NaN  NaN   C1   D1
# 5  K9  NaN  NaN   C9   D9

# %%
pd.merge(left, right, how='left', on=['key'])
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K2  A2  B2   C2   D2
# 2  K5  A5  B5  NaN  NaN
# 3  K3  A3  B3  NaN  NaN

# %%
pd.merge(left, right, how='right', on=['key'])
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K9  NaN  NaN  C9  D9

# %%
#Join
left.set_index('key',inplace=True)

# %%
right.set_index('key',inplace=True)

# %%
left.join(right,how='inner')
# Out:
#       A   B   C   D
# key
# K0   A0  B0  C0  D0
# K2   A2  B2  C2  D2

# %%
left.join(right,how='outer')
# Out:
#        A    B    C    D
# key
# K0    A0   B0   C0   D0
# K1   NaN  NaN   C1   D1
# K2    A2   B2   C2   D2
# K3    A3   B3  NaN  NaN
# K5    A5   B5  NaN  NaN
# K9   NaN  NaN   C9   D9

# %%
left.join(right,how='left')
# Out:
#       A   B    C    D
# key
# K0   A0  B0   C0   D0
# K2   A2  B2   C2   D2
# K5   A5  B5  NaN  NaN
# K3   A3  B3  NaN  NaN

# %%
left.join(right,how='right')
# Out:
#        A    B   C   D
# key
# K0    A0   B0  C0  D0
# K1   NaN  NaN  C1  D1
# K2    A2   B2  C2  D2
# K9   NaN  NaN  C9  D9
